# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/LAWMANS/Desktop/PYTHON/inventory.csv')
df
# Out:
#      ID#             Product  Cost Per Unit Quantity On Hand
# 0   2001            T-Shirts           5.25           4,231
# 1   2002              Shorts          10.05           1,961
# 2   2004  Long Sleeve Shirts          10.29           6,084
# 3   2005               Vests          12.32           1,837
# 4   2006  Button Down Shirts          14.99           3,312
# 5   2007       Baseball Hats           5.50           1,322
# 6   2011       Bathing Suits          10.05           5,631
# 7   2012        Casual Pants          13.72           4,289
# 8   2013              Gloves           3.39           6,043
# 9   2015         Dress Pants          15.82           4,773
# 10  2022        Tennis Shoes          20.99           2,874
# 11  2023           Toboggans           3.88           3,391
# 12  2027            Sweaters          12.49           4,519
# 13  2030             Dresses          18.62           3,001
# 14  2031               Socks           2.01           4,968
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      ID#             Product  Cost Per Unit Quantity On Hand
# 0   2001            T-Shirts           5.25           4,231
# 1   2002              Shorts          10.05           1,961
# 2   2004  Long Sleeve Shirts          10.29           6,084
# 3   2005               Vests          12.32           1,837
# 4   2006  Button Down Shirts          14.99           3,312
# 5   2007       Baseball Hats           5.50           1,322
# 6   2011       Bathing Suits          10.05           5,631
# 7   2012        Casual Pants          13.72           4,289
# 8   2013              Gloves           3.39           6,043
# 9   2015         Dress Pants          15.82           4,773
# 10  2022        Tennis Shoes          20.99           2,874
# 11  2023           Toboggans           3.88           3,391
# 12  2027            Sweaters          12.49           4,519
# 13  2030             Dresses          18.62           3,001
# ...

# %%
df[['Product','Quantity On Hand']]
# Out:
#                Product Quantity On Hand
# 0             T-Shirts           4,231
# 1               Shorts           1,961
# 2   Long Sleeve Shirts           6,084
# 3                Vests           1,837
# 4   Button Down Shirts           3,312
# 5        Baseball Hats           1,322
# 6        Bathing Suits           5,631
# 7         Casual Pants           4,289
# 8               Gloves           6,043
# 9          Dress Pants           4,773
# 10        Tennis Shoes           2,874
# 11           Toboggans           3,391
# 12            Sweaters           4,519
# 13             Dresses           3,001
# 14               Socks           4,968
# 15       Light Jackets           2,137
# 16      Winter Jackets           2,873
# 17               Belts           1,731
# 18             Sandals           5,930
# 19               Boots           2,039
# 20              Scarfs           3,576
# 21         Sun Glasses           3,437
# 22         Dress Shoes           2,942
# ...

# %%
df[['Product','Cost Per Unit']].plot(kind ='bar')

# %%
ydf = pd.read_csv('C:/Users/LAWMANS/Desktop/PYTHON/yield.csv')
ydf
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
ydf.shape
# Out:
# (28242, 8)

# %%
ydf[['Item','hg/ha_yield']]
# Out:
#                  Item  hg/ha_yield
# 0               Maize        36613
# 1            Potatoes        66667
# 2         Rice, paddy        23333
# 3             Sorghum        12500
# 4            Soybeans         7000
# ...               ...          ...
# 28237     Rice, paddy        22581
# 28238         Sorghum         3066
# 28239        Soybeans        13142
# 28240  Sweet potatoes        22222
# 28241           Wheat        22888
#
# [28242 rows x 2 columns]

# %%
ydf[['Year','hg/ha_yield']]
# Out:
#        Year  hg/ha_yield
# 0      1990        36613
# 1      1990        66667
# 2      1990        23333
# 3      1990        12500
# 4      1990         7000
# ...     ...          ...
# 28237  2013        22581
# 28238  2013         3066
# 28239  2013        13142
# 28240  2013        22222
# 28241  2013        22888
#
# [28242 rows x 2 columns]

# %%
ydf.mean
# Out:
# <bound method DataFrame.mean of        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# ...

# %%
ydf[['Year','pesticides_tonnes']]
# Out:
#        Year  pesticides_tonnes
# 0      1990             121.00
# 1      1990             121.00
# 2      1990             121.00
# 3      1990             121.00
# 4      1990             121.00
# ...     ...                ...
# 28237  2013            2550.07
# 28238  2013            2550.07
# 28239  2013            2550.07
# 28240  2013            2550.07
# 28241  2013            2550.07
#
# [28242 rows x 2 columns]

# %%
tdf = pd.read_csv('C:/Users/LAWMANS/Desktop/test.csv')
tdf
# Out:
#     Unnamed: 0  gender  tenure
# 0            0    male   266.0
# 1            1  female     6.0
# 2            2    male    13.0
# 3            3  female    93.0
# 4            4    male    82.0
# 5            5    male    15.0
# 6            6    male    12.0
# 7            7  female     0.0
# 8            8    male    81.0
# 9            9    male   171.0
# 10          10    male    98.0
# 11          11    male    55.0
# 12          12    male   106.0
# 13          13    male    61.0
# 14          14  female     0.0
# 15          15  female    16.0
# 16          16  female    34.0
# 17          17  female    25.0
# 18          18  female     4.0
# 19          19    male     9.0

# %%
tdf.describe
# Out:
# <bound method NDFrame.describe of     Unnamed: 0  gender  tenure
# 0            0    male   266.0
# 1            1  female     6.0
# 2            2    male    13.0
# 3            3  female    93.0
# 4            4    male    82.0
# 5            5    male    15.0
# 6            6    male    12.0
# 7            7  female     0.0
# 8            8    male    81.0
# 9            9    male   171.0
# 10          10    male    98.0
# 11          11    male    55.0
# 12          12    male   106.0
# 13          13    male    61.0
# 14          14  female     0.0
# 15          15  female    16.0
# 16          16  female    34.0
# 17          17  female    25.0
# 18          18  female     4.0
# 19          19    male     9.0>

# %%
tdf.dtypes
# Out:
# Unnamed: 0      int64
# gender         object
# tenure        float64
# dtype: object

# %%
tdf.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0  gender  tenure
# 0            0    male   266.0
# 1            1  female     6.0
# 2            2    male    13.0
# 3            3  female    93.0
# 4            4    male    82.0
# 5            5    male    15.0
# 6            6    male    12.0
# 7            7  female     0.0
# 8            8    male    81.0
# 9            9    male   171.0
# 10          10    male    98.0
# 11          11    male    55.0
# 12          12    male   106.0
# 13          13    male    61.0
# 14          14  female     0.0
# 15          15  female    16.0
# 16          16  female    34.0
# 17          17  female    25.0
# 18          18  female     4.0
# 19          19    male     9.0>

# %%
tdf.plot(kind ='bar')

# %%
tdf.groupby(['gender']).count().T.sum().plot(kind ='pie')
